# %%
from PIL import Image

# %%
path = 'data/IR-MNIST/Train Samples/image_0.jpg'

# %%
img = Image.open(path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FC0381D47B8>

# %%
img.resize((64,64)).resize((224,224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FC0382008D0>

# %%
img.resize((64,64), Image.BICUBIC).resize((224,224), Image.BICUBIC)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FC038B16CF8>

# %%
img.resize((64,64), Image.BILINEAR).resize((224,224), Image.BILINEAR)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FC038AB5EB8>

# %%
img.resize((64,64), Image.LANCZOS).resize((224,224), Image.LANCZOS)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FC038200A90>

# %%
img.resize((128,128)).resize((224,224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FC038206CC0>

# %%
img.resize((128,128), Image.LANCZOS).resize((224,224), Image.LANCZOS)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FC038200BE0>

# %%
img.resize((108,108), Image.LANCZOS).resize((224,224), Image.LANCZOS)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FC02265D5F8>
